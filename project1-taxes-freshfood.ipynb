# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
from scipy.stats import linregress

# %%
taxes_df_path = r"C:\Users\natal\OneDrive\Desktop\project_1_files\TAXES2.csv"
local_df_path = r"C:\Users\natal\OneDrive\Desktop\project_1_files\merged_farmers_markets.csv"
stores_df_path = r"C:\Users\natal\OneDrive\Desktop\project_1_files\STORES.csv"

# %%
stores_df = pd.read_csv(stores_df_path)
stores_df.head()
# Out:
#    FIPS State   County  GROC11  GROC16  PCH_GROC_11_16  GROCPTH11  GROCPTH16  \
# 0  1001    AL  Autauga       5       3      -40.000000   0.090581   0.054271
# 1  1003    AL  Baldwin      27      29        7.407407   0.144746   0.139753
# 2  1005    AL  Barbour       6       4      -33.333333   0.219370   0.155195
# 3  1007    AL     Bibb       6       5      -16.666667   0.263794   0.220916
# 4  1009    AL   Blount       7       5      -28.571429   0.121608   0.086863
#
#    PCH_GROCPTH_11_16  SUPERC11  ...  PCH_SNAPS_12_17  SNAPSPTH12  SNAPSPTH17  \
# 0         -40.085748         1  ...        19.376392    0.674004    0.804747
# 1          -3.449328         6  ...        36.927711    0.725055    0.890836
# 2         -29.254287         0  ...         3.349282    1.280590    1.424614
# 3         -16.254289         1  ...        11.794872    0.719122    0.801423
# 4         -28.571429         1  ...         5.701754    0.657144    0.692374
#
#    PCH_SNAPSPTH_12_17  WICS11  WICS16  PCH_WICS_11_16  WICSPTH11  WICSPTH16  \
# 0           19.397900     5.0     5.0        0.000000   0.090567   0.090511
# 1           22.864524    26.0    28.0        7.692307   0.139380   0.134802
# 2           11.246689     7.0     6.0      -14.285714   0.255942   0.232387
# 3           11.444711     6.0     5.0      -16.666666   0.263771   0.221474
# 4            5.361034     8.0     8.0        0.000000   0.139000   0.139089
#
#    PCH_WICSPTH_11_16
# 0          -0.061543
# 1          -3.284727
# 2          -9.203081
# 3         -16.035471
# 4           0.064332
#
# [5 rows x 39 columns]

# %%
stores_df['County & State'] = stores_df['County'] + ", " + stores_df['State']
stores_df.drop(['County', 'State'], axis=1, inplace=True)
stores_df = stores_df[['County & State'] + [col for col in stores_df.columns if col != 'County & State']]
stores_df.head()
# Out:
#   County & State  FIPS  GROC11  GROC16  PCH_GROC_11_16  GROCPTH11  GROCPTH16  \
# 0    Autauga, AL  1001       5       3      -40.000000   0.090581   0.054271
# 1    Baldwin, AL  1003      27      29        7.407407   0.144746   0.139753
# 2    Barbour, AL  1005       6       4      -33.333333   0.219370   0.155195
# 3       Bibb, AL  1007       6       5      -16.666667   0.263794   0.220916
# 4     Blount, AL  1009       7       5      -28.571429   0.121608   0.086863
#
#    PCH_GROCPTH_11_16  SUPERC11  SUPERC16  ...  PCH_SNAPS_12_17  SNAPSPTH12  \
# 0         -40.085748         1         1  ...        19.376392    0.674004
# 1          -3.449328         6         7  ...        36.927711    0.725055
# 2         -29.254287         0         1  ...         3.349282    1.280590
# 3         -16.254289         1         1  ...        11.794872    0.719122
# 4         -28.571429         1         1  ...         5.701754    0.657144
#
#    SNAPSPTH17  PCH_SNAPSPTH_12_17  WICS11  WICS16  PCH_WICS_11_16  WICSPTH11  \
# 0    0.804747           19.397900     5.0     5.0        0.000000   0.090567
# 1    0.890836           22.864524    26.0    28.0        7.692307   0.139380
# 2    1.424614           11.246689     7.0     6.0      -14.285714   0.255942
# 3    0.801423           11.444711     6.0     5.0      -16.666666   0.263771
# 4    0.692374            5.361034     8.0     8.0        0.000000   0.139000
#
#    WICSPTH16  PCH_WICSPTH_11_16
# 0   0.090511          -0.061543
# 1   0.134802          -3.284727
# 2   0.232387          -9.203081
# 3   0.221474         -16.035471
# 4   0.139089           0.064332
#
# [5 rows x 38 columns]

# %%
local_df = pd.read_csv(local_df_path)
local_df.head()
# Out:
#   County & State  FMRKT13  FMRKT18  PCH_FMRKT_13_18  FMRKTPTH13  FMRKTPTH18  \
# 0    Autauga, AL      1.0      1.0         0.000000    0.018277    0.017985
# 1    Baldwin, AL      4.0      4.0         0.000000    0.020525    0.018347
# 2    Barbour, AL      3.0      4.0        33.333332    0.111342    0.160765
# 3       Bibb, AL      1.0      1.0         0.000000    0.044413    0.044643
# 4     Blount, AL      1.0      1.0         0.000000    0.017358    0.017289
#
#    PCH_FMRKTPTH_13_18  FMRKT_SNAP18  PCT_FMRKT_SNAP18  FMRKT_WIC18  ...  \
# 0           -1.597097           0.0               0.0          0.0  ...
# 1          -10.611780           0.0               0.0          0.0  ...
# 2           44.388626           2.0              50.0          0.0  ...
# 3            0.517858           0.0               0.0          0.0  ...
# 4           -0.395916           0.0               0.0          1.0  ...
#
#    FMRKT_CREDIT18  PCT_FMRKT_CREDIT18  FMRKT_FRVEG18  PCT_FMRKT_FRVEG18  \
# 0             0.0                 0.0            1.0              100.0
# 1             2.0                50.0            3.0               75.0
# 2             2.0                50.0            2.0               50.0
# 3             0.0                 0.0            0.0                0.0
# 4             0.0                 0.0            1.0              100.0
#
#    FMRKT_ANMLPROD18  PCT_FMRKT_ANMLPROD18  FMRKT_BAKED18  PCT_FMRKT_BAKED18  \
# 0               0.0                   0.0            1.0              100.0
# 1               4.0                 100.0            3.0               75.0
# 2               0.0                   0.0            2.0               50.0
# 3               0.0                   0.0            0.0                0.0
# 4               1.0                 100.0            1.0              100.0
#
#    FMRKT_OTHERFOOD18  PCT_FMRKT_OTHERFOOD18
# 0                1.0                  100.0
# 1                3.0                   75.0
# 2                2.0                   50.0
# 3                0.0                    0.0
# 4                1.0                  100.0
#
# [5 rows x 25 columns]

# %%
taxes_df = pd.read_csv(taxes_df_path)
taxes_df.head()
# Out:
#   County & State  FIPS  SODATAX_STORES14  SODATAX_VENDM14  CHIPSTAX_STORES14  \
# 0    Autauga, AL  1001               4.0              4.0                4.0
# 1    Baldwin, AL  1003               4.0              4.0                4.0
# 2    Barbour, AL  1005               4.0              4.0                4.0
# 3       Bibb, AL  1007               4.0              4.0                4.0
# 4     Blount, AL  1009               4.0              4.0                4.0
#
#    CHIPSTAX_VENDM14  FOOD_TAX14
# 0               4.0         4.0
# 1               4.0         4.0
# 2               4.0         4.0
# 3               4.0         4.0
# 4               4.0         4.0

# %%
local_stores_merge = pd.merge(stores_df, local_df, on='County & State', how='inner')
local_stores_merge
# Out:
#       County & State   FIPS  GROC11  GROC16  PCH_GROC_11_16  GROCPTH11  \
# 0        Autauga, AL   1001       5       3      -40.000000   0.090581
# 1        Baldwin, AL   1003      27      29        7.407407   0.144746
# 2        Barbour, AL   1005       6       4      -33.333333   0.219370
# 3           Bibb, AL   1007       6       5      -16.666667   0.263794
# 4         Blount, AL   1009       7       5      -28.571429   0.121608
# ...              ...    ...     ...     ...             ...        ...
# 3152  Sweetwater, WY  56037       5       4      -20.000000   0.113603
# 3153       Teton, WY  56039       5      11      120.000000   0.232818
# 3154       Uinta, WY  56041       3       2      -33.333333   0.143548
# 3155    Washakie, WY  56043       2       2        0.000000   0.236407
# 3156      Weston, WY  56045       4       4        0.000000   0.560146
#
#       GROCPTH16  PCH_GROCPTH_11_16  SUPERC11  SUPERC16  ...  FMRKT_CREDIT18  \
# 0      0.054271         -40.085748         1         1  ...             0.0
# 1      0.139753          -3.449328         6         7  ...             2.0
# 2      0.155195         -29.254287         0         1  ...             2.0
# 3      0.220916         -16.254289         1         1  ...             0.0
# 4      0.086863         -28.571429         1         1  ...             0.0
# ...         ...                ...       ...       ...  ...             ...
# 3152   0.090406         -20.419482         1         1  ...             0.0
# 3153   0.474547         103.827437         0         0  ...             2.0
# 3154   0.096567         -32.728180         1         1  ...             2.0
# 3155   0.244260           3.321935         0         0  ...             1.0
# 3156   0.555710          -0.791887         0         0  ...             0.0
#
#       PCT_FMRKT_CREDIT18  FMRKT_FRVEG18  PCT_FMRKT_FRVEG18  FMRKT_ANMLPROD18  \
# 0               0.000000            1.0              100.0               0.0
# 1              50.000000            3.0               75.0               4.0
# 2              50.000000            2.0               50.0               0.0
# 3               0.000000            0.0                0.0               0.0
# 4               0.000000            1.0              100.0               1.0
# ...                  ...            ...                ...               ...
# 3152            0.000000            0.0                0.0               0.0
# 3153           66.666664            3.0              100.0               2.0
# 3154          100.000000            0.0                0.0               0.0
# 3155           50.000000            2.0              100.0               2.0
# 3156            0.000000            0.0                0.0               0.0
#
#       PCT_FMRKT_ANMLPROD18  FMRKT_BAKED18  PCT_FMRKT_BAKED18  \
# 0                 0.000000            1.0              100.0
# 1               100.000000            3.0               75.0
# 2                 0.000000            2.0               50.0
# 3                 0.000000            0.0                0.0
# 4               100.000000            1.0              100.0
# ...                    ...            ...                ...
# 3152              0.000000            0.0                0.0
# 3153             66.666664            3.0              100.0
# 3154              0.000000            0.0                0.0
# 3155            100.000000            2.0              100.0
# 3156              0.000000            0.0                0.0
#
#       FMRKT_OTHERFOOD18  PCT_FMRKT_OTHERFOOD18
# 0                   1.0             100.000000
# 1                   3.0              75.000000
# 2                   2.0              50.000000
# 3                   0.0               0.000000
# 4                   1.0             100.000000
# ...                 ...                    ...
# 3152                0.0               0.000000
# 3153                2.0              66.666664
# 3154                0.0               0.000000
# 3155                1.0              50.000000
# 3156                0.0               0.000000
#
# [3157 rows x 62 columns]

# %%
final_merge = pd.merge(local_stores_merge, taxes_df, on='County & State', how='inner')
final_merge
# Out:
#       County & State  FIPS_x  GROC11  GROC16  PCH_GROC_11_16  GROCPTH11  \
# 0        Autauga, AL    1001       5       3      -40.000000   0.090581
# 1        Baldwin, AL    1003      27      29        7.407407   0.144746
# 2        Barbour, AL    1005       6       4      -33.333333   0.219370
# 3           Bibb, AL    1007       6       5      -16.666667   0.263794
# 4         Blount, AL    1009       7       5      -28.571429   0.121608
# ...              ...     ...     ...     ...             ...        ...
# 3180  Sweetwater, WY   56037       5       4      -20.000000   0.113603
# 3181       Teton, WY   56039       5      11      120.000000   0.232818
# 3182       Uinta, WY   56041       3       2      -33.333333   0.143548
# 3183    Washakie, WY   56043       2       2        0.000000   0.236407
# 3184      Weston, WY   56045       4       4        0.000000   0.560146
#
#       GROCPTH16  PCH_GROCPTH_11_16  SUPERC11  SUPERC16  ...  FMRKT_BAKED18  \
# 0      0.054271         -40.085748         1         1  ...            1.0
# 1      0.139753          -3.449328         6         7  ...            3.0
# 2      0.155195         -29.254287         0         1  ...            2.0
# 3      0.220916         -16.254289         1         1  ...            0.0
# 4      0.086863         -28.571429         1         1  ...            1.0
# ...         ...                ...       ...       ...  ...            ...
# 3180   0.090406         -20.419482         1         1  ...            0.0
# 3181   0.474547         103.827437         0         0  ...            3.0
# 3182   0.096567         -32.728180         1         1  ...            0.0
# 3183   0.244260           3.321935         0         0  ...            2.0
# 3184   0.555710          -0.791887         0         0  ...            0.0
#
#       PCT_FMRKT_BAKED18  FMRKT_OTHERFOOD18  PCT_FMRKT_OTHERFOOD18  FIPS_y  \
# 0                 100.0                1.0             100.000000    1001
# 1                  75.0                3.0              75.000000    1003
# 2                  50.0                2.0              50.000000    1005
# 3                   0.0                0.0               0.000000    1007
# 4                 100.0                1.0             100.000000    1009
# ...                 ...                ...                    ...     ...
# 3180                0.0                0.0               0.000000   56037
# 3181              100.0                2.0              66.666664   56039
# 3182                0.0                0.0               0.000000   56041
# 3183              100.0                1.0              50.000000   56043
# 3184                0.0                0.0               0.000000   56045
#
#       SODATAX_STORES14  SODATAX_VENDM14  CHIPSTAX_STORES14  CHIPSTAX_VENDM14  \
# 0                  4.0              4.0                4.0               4.0
# 1                  4.0              4.0                4.0               4.0
# 2                  4.0              4.0                4.0               4.0
# 3                  4.0              4.0                4.0               4.0
# 4                  4.0              4.0                4.0               4.0
# ...                ...              ...                ...               ...
# 3180               0.0              4.0                0.0               4.0
# 3181               0.0              4.0                0.0               4.0
# 3182               0.0              4.0                0.0               4.0
# 3183               0.0              4.0                0.0               4.0
# 3184               0.0              4.0                0.0               4.0
#
#       FOOD_TAX14
# 0            4.0
# 1            4.0
# 2            4.0
# 3            4.0
# 4            4.0
# ...          ...
# 3180         0.0
# 3181         0.0
# 3182         0.0
# 3183         0.0
# 3184         0.0
#
# [3185 rows x 68 columns]

# %%
filtered_counties = final_merge[(final_merge['SODATAX_STORES14'] == 1.5) | (final_merge['SODATAX_STORES14'] == 7)]
filtered_counties
# Out:
#           County & State  FIPS_x  GROC11  GROC16  PCH_GROC_11_16  GROCPTH11  \
# 111         Arkansas, AR    5001       3       3        0.000000   0.158991
# 112           Ashley, AR    5003       7       2      -71.428571   0.322983
# 113           Baxter, AR    5005       7       8       14.285714   0.169323
# 114           Benton, AR    5007      27      37       37.037037   0.117993
# 115            Boone, AR    5009       5       7       40.000000   0.134905
# ...                  ...     ...     ...     ...             ...        ...
# 2991         Suffolk, VA   51800      14      14        0.000000   0.165184
# 2992  Virginia Beach, VA   51810      71      77        8.450704   0.160319
# 2993      Waynesboro, VA   51820       8      10       25.000000   0.379057
# 2994    Williamsburg, VA   51830       4       5       25.000000   0.283366
# 2995      Winchester, VA   51840      12       9      -25.000000   0.450079
#
#       GROCPTH16  PCH_GROCPTH_11_16  SUPERC11  SUPERC16  ...  FMRKT_BAKED18  \
# 111    0.164699           3.590447         1         1  ...            0.0
# 112    0.097570         -69.790781         1         1  ...            0.0
# 113    0.194434          14.830130         1         1  ...            0.0
# 114    0.143021          21.211014         7         7  ...            6.0
# 115    0.188218          39.518163         1         1  ...            2.0
# ...         ...                ...       ...       ...  ...            ...
# 2991   0.156785          -5.084328         2         2  ...            1.0
# 2992   0.170579           6.399913         5         8  ...            3.0
# 2993   0.458674          21.003807         1         1  ...            0.0
# 2994   0.334403          18.010968         0         0  ...            1.0
# 2995   0.326489         -27.459552         1         1  ...            1.0
#
#       PCT_FMRKT_BAKED18  FMRKT_OTHERFOOD18  PCT_FMRKT_OTHERFOOD18  FIPS_y  \
# 111            0.000000                0.0               0.000000    5001
# 112            0.000000                0.0               0.000000    5003
# 113            0.000000                0.0               0.000000    5005
# 114           75.000000                6.0              75.000000    5007
# 115           66.666664                2.0              66.666664    5009
# ...                 ...                ...                    ...     ...
# 2991          50.000000                1.0              50.000000   51800
# 2992          60.000000                3.0              60.000000   51810
# 2993           0.000000                0.0               0.000000   51820
# 2994         100.000000                1.0             100.000000   51830
# 2995         100.000000                1.0             100.000000   51840
#
#       SODATAX_STORES14  SODATAX_VENDM14  CHIPSTAX_STORES14  CHIPSTAX_VENDM14  \
# 111                1.5              1.5                1.5               1.5
# 112                1.5              1.5                1.5               1.5
# 113                1.5              1.5                1.5               1.5
# 114                1.5              1.5                1.5               1.5
# 115                1.5              1.5                1.5               1.5
# ...                ...              ...                ...               ...
# 2991               1.5              5.3                1.5               5.3
# 2992               1.5              5.3                1.5               5.3
# 2993               1.5              5.3                1.5               5.3
# 2994               1.5              5.3                1.5               5.3
# 2995               1.5              5.3                1.5               5.3
#
#       FOOD_TAX14
# 111          1.5
# 112          1.5
# 113          1.5
# 114          1.5
# 115          1.5
# ...          ...
# 2991         1.5
# 2992         1.5
# 2993         1.5
# 2994         1.5
# 2995         1.5
#
# [439 rows x 68 columns]

# %%
soda_tax_7_percent = final_merge[final_merge['SODATAX_STORES14'] == 7]
soda_tax_7_percent
# Out:
#        County & State  FIPS_x  GROC11  GROC16  PCH_GROC_11_16  GROCPTH11  \
# 697         Adams, IN   18001       6       4      -33.333333   0.174561
# 698         Allen, IN   18003      40      56       40.000000   0.111487
# 699   Bartholomew, IN   18005      16      12      -25.000000   0.206241
# 700        Benton, IN   18007       2       2        0.000000   0.225785
# 701     Blackford, IN   18009       5       3      -40.000000   0.395163
# ...               ...     ...     ...     ...             ...        ...
# 2323      Bristol, RI   44001       6       7       16.666667   0.121921
# 2324         Kent, RI   44003      24      21      -12.500000   0.145252
# 2325      Newport, RI   44005      10      14       40.000000   0.120262
# 2326   Providence, RI   44007     129     135        4.651163   0.205385
# 2327   Washington, RI   44009      32      28      -12.500000   0.253022
#
#       GROCPTH16  PCH_GROCPTH_11_16  SUPERC11  SUPERC16  ...  FMRKT_BAKED18  \
# 697    0.113533         -34.960642         1         1  ...            1.0
# 698    0.151363          35.767518         9        11  ...            8.0
# 699    0.146568         -28.933531         3         3  ...            3.0
# 700    0.231080           2.345465         0         0  ...            0.0
# 701    0.248447         -37.127950         0         0  ...            0.0
# ...         ...                ...       ...       ...  ...            ...
# 2323   0.143214          17.463890         0         0  ...            3.0
# 2324   0.128291         -11.676798         3         2  ...            2.0
# 2325   0.167675          39.424876         1         1  ...            3.0
# 2326   0.212424           3.427174         1         3  ...           10.0
# 2327   0.222256         -12.159671         1         2  ...            6.0
#
#       PCT_FMRKT_BAKED18  FMRKT_OTHERFOOD18  PCT_FMRKT_OTHERFOOD18  FIPS_y  \
# 697          100.000000                1.0             100.000000   18001
# 698          100.000000                8.0             100.000000   18003
# 699           75.000000                4.0             100.000000   18005
# 700            0.000000                0.0               0.000000   18007
# 701            0.000000                0.0               0.000000   18009
# ...                 ...                ...                    ...     ...
# 2323         100.000000                3.0             100.000000   44001
# 2324          50.000000                3.0              75.000000   44003
# 2325         100.000000                3.0             100.000000   44005
# 2326          55.555557               11.0              61.111111   44007
# 2327          75.000000                6.0              75.000000   44009
#
#       SODATAX_STORES14  SODATAX_VENDM14  CHIPSTAX_STORES14  CHIPSTAX_VENDM14  \
# 697                7.0              7.0                0.0               7.0
# 698                7.0              7.0                0.0               7.0
# 699                7.0              7.0                0.0               7.0
# 700                7.0              7.0                0.0               7.0
# 701                7.0              7.0                0.0               7.0
# ...                ...              ...                ...               ...
# 2323               7.0              7.0                0.0               0.0
# 2324               7.0              7.0                0.0               0.0
# 2325               7.0              7.0                0.0               0.0
# 2326               7.0              7.0                0.0               0.0
# 2327               7.0              7.0                0.0               0.0
#
#       FOOD_TAX14
# 697          0.0
# 698          0.0
# 699          0.0
# 700          0.0
# 701          0.0
# ...          ...
# 2323         0.0
# 2324         0.0
# 2325         0.0
# 2326         0.0
# 2327         0.0
#
# [200 rows x 68 columns]

# %%
aggregation = soda_tax_7_percent[["CONVSPTH16", "GROC16", "FMRKTPTH18"]].sum()

plt.figure(figsize=(10, 6))
bar_plot = aggregation.plot(kind='bar', color=['red', 'yellow', 'green'])
plt.title('Count of Stores Per 1000 People in 7% Soda Tax Counties')
plt.ylabel('Count')

bar_plot.set_xticklabels(["Convenience Stores", "Grocery Stores", "Farmer's Markets"], rotation=45)

plt.grid(axis='y')

for i in range(len(aggregation)):
    plt.text(i, aggregation[i], round(aggregation[i], 2), ha='center', va='bottom')

plt.show()

# %%
soda_tax_1_percent = final_merge[final_merge['SODATAX_STORES14'] == 1.5]
soda_tax_1_percent
# Out:
#           County & State  FIPS_x  GROC11  GROC16  PCH_GROC_11_16  GROCPTH11  \
# 111         Arkansas, AR    5001       3       3        0.000000   0.158991
# 112           Ashley, AR    5003       7       2      -71.428571   0.322983
# 113           Baxter, AR    5005       7       8       14.285714   0.169323
# 114           Benton, AR    5007      27      37       37.037037   0.117993
# 115            Boone, AR    5009       5       7       40.000000   0.134905
# ...                  ...     ...     ...     ...             ...        ...
# 2991         Suffolk, VA   51800      14      14        0.000000   0.165184
# 2992  Virginia Beach, VA   51810      71      77        8.450704   0.160319
# 2993      Waynesboro, VA   51820       8      10       25.000000   0.379057
# 2994    Williamsburg, VA   51830       4       5       25.000000   0.283366
# 2995      Winchester, VA   51840      12       9      -25.000000   0.450079
#
#       GROCPTH16  PCH_GROCPTH_11_16  SUPERC11  SUPERC16  ...  FMRKT_BAKED18  \
# 111    0.164699           3.590447         1         1  ...            0.0
# 112    0.097570         -69.790781         1         1  ...            0.0
# 113    0.194434          14.830130         1         1  ...            0.0
# 114    0.143021          21.211014         7         7  ...            6.0
# 115    0.188218          39.518163         1         1  ...            2.0
# ...         ...                ...       ...       ...  ...            ...
# 2991   0.156785          -5.084328         2         2  ...            1.0
# 2992   0.170579           6.399913         5         8  ...            3.0
# 2993   0.458674          21.003807         1         1  ...            0.0
# 2994   0.334403          18.010968         0         0  ...            1.0
# 2995   0.326489         -27.459552         1         1  ...            1.0
#
#       PCT_FMRKT_BAKED18  FMRKT_OTHERFOOD18  PCT_FMRKT_OTHERFOOD18  FIPS_y  \
# 111            0.000000                0.0               0.000000    5001
# 112            0.000000                0.0               0.000000    5003
# 113            0.000000                0.0               0.000000    5005
# 114           75.000000                6.0              75.000000    5007
# 115           66.666664                2.0              66.666664    5009
# ...                 ...                ...                    ...     ...
# 2991          50.000000                1.0              50.000000   51800
# 2992          60.000000                3.0              60.000000   51810
# 2993           0.000000                0.0               0.000000   51820
# 2994         100.000000                1.0             100.000000   51830
# 2995         100.000000                1.0             100.000000   51840
#
#       SODATAX_STORES14  SODATAX_VENDM14  CHIPSTAX_STORES14  CHIPSTAX_VENDM14  \
# 111                1.5              1.5                1.5               1.5
# 112                1.5              1.5                1.5               1.5
# 113                1.5              1.5                1.5               1.5
# 114                1.5              1.5                1.5               1.5
# 115                1.5              1.5                1.5               1.5
# ...                ...              ...                ...               ...
# 2991               1.5              5.3                1.5               5.3
# 2992               1.5              5.3                1.5               5.3
# 2993               1.5              5.3                1.5               5.3
# 2994               1.5              5.3                1.5               5.3
# 2995               1.5              5.3                1.5               5.3
#
#       FOOD_TAX14
# 111          1.5
# 112          1.5
# 113          1.5
# 114          1.5
# 115          1.5
# ...          ...
# 2991         1.5
# 2992         1.5
# 2993         1.5
# 2994         1.5
# 2995         1.5
#
# [239 rows x 68 columns]

# %%
aggregation = soda_tax_1_percent[["CONVSPTH16", "GROC16", "FMRKTPTH18"]].sum()

plt.figure(figsize=(10, 6))
bar_plot = aggregation.plot(kind='bar', color=['red', 'yellow', 'green'])
plt.title('Count of Stores Per 1000 People in 1.5% Soda Tax Counties')
plt.ylabel('Count')

bar_plot.set_xticklabels(["Convenience Stores", "Grocery Stores", "Farmer's Markets"], rotation=45)

plt.grid(axis='y')

for i in range(len(aggregation)):
    plt.text(i, aggregation[i], round(aggregation[i], 2), ha='center', va='bottom')

plt.show()
